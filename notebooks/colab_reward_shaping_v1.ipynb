# %% [markdown]
# # Colab reward shaping v1
#
# 本 notebook 用于改进版实验，不和 baseline 混用。
#
# 目标：
# - 重新建立 Colab 环境
# - 同步仓库最新代码
# - 明确 reward shaping 设计
# - 预留改进版训练与结果分析位置

# %% [markdown]
# ## 1. Clone repo

# %%
# !git clone https://github.com/WonderfulClaire/low_altitude_marl.git
# %cd /content/low_altitude_marl
# !ls

# %% [markdown]
# ## 2. Install dependencies

# %%
# %cd /content/low_altitude_marl
# !python -m pip install --upgrade pip
# !python -m pip install -r requirements.txt

# %% [markdown]
# ## 3. Read design docs

# %%
# %cd /content/low_altitude_marl
# !sed -n '1,200p' src/reward_shaping_design.md
print('\n' + '='*80 + '\n')
# !sed -n '1,200p' src/scenario_mapping.md

# %% [markdown]
# ## 4. TODO: implement reward shaping
# 后续在这里接入改进版代码后，再运行改进版实验。

# %%
print('TODO: add reward shaping implementation here')

# %% [markdown]
# ## 5. Placeholder for improved run

# %%
# Example placeholder
# import os
# os.environ['WANDB_MODE'] = 'disabled'
# !python -m benchmarl.run ...

# %% [markdown]
# ## 6. Placeholder for improved run summary

# %%
# RUN_ROOT = '/content/low_altitude_marl/outputs/REPLACE_ME'
# !python src/metrics_summary.py "$RUN_ROOT"
